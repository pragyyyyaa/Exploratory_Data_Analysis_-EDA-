# %% [markdown]
# ## Context
#
# Starting in 2008, every year Forbes Magazine publishes a list of America's best colleges. When it comes to the question everyone seems to be asking, “Is college worth it? this published list of colleges comes handy to take a decision based on student's requirement or desire.
#
# The mission of the college ranking by Forbes Magazine is to conduct an annual review of the undergraduate institutions that deliver the top academics, best experiences, career success and lowest debt. Whether a school is in the Top 10 or near the bottom of the list, the 650 colleges are the best in the country.
#
# For most families, choosing a four-year college is one of the biggest and most expensive decisions they can make. For students, this time of their life may layout their future plans. So choose carefully.

# %% [markdown]
# ## About Data
#
# The data set contains the rankings of 650 Unites States colleges along with various other statistics pertaining to each school.

# %% [markdown]
# ### Load required packages

# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Pragya Gupta'

# %%
os.chdir('C:\\Users\\Pragya Gupta\\Downloads')
os.getcwd()
# Out:
# 'C:\\Users\\Pragya Gupta\\Downloads'

# %% [markdown]
# ### Load the data into pandas dataframe and view the details

# %%
forbes_data = pd.read_csv('ForbesAmericasTopColleges2019.csv')

# %%
forbes_data
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 645   646            New Mexico State University   Las Cruces    NM
# 646   647               Indiana State University  Terre Haute    IN
# 647   648              Emory &amp; Henry College        Emory    VA
# 648   649                          Wells College       Aurora    NY
# 649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# 1          Private                      8402               17534    13261.0
# 2          Private                      6483               12974    18627.0
# 3          Private                      4680               11466    20771.0
# 4          Private                      5659                8273     9327.0
# ..             ...                       ...                 ...        ...
# 645         Public                     13379               14432     8625.0
# 646         Public                     13626               13763    13012.0
# 647        Private                      1094                1226    19340.0
# 648        Private                       488                 516    22828.0
# 649        Private                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 0              49870.0              69600       146800.0              5.0
# 1              50134.0              69109       145200.0              5.0
# 2              50897.0              71290       138300.0              7.0
# 3              43248.0              67430       155200.0              7.0
# 4              48088.0              66150       139400.0              6.0
# ..                 ...                ...            ...              ...
# 645             9582.0              34720        96700.0             64.0
# 646             9297.0              32938        85600.0             85.0
# 647            27155.0              48100        70700.0             72.0
# 648            30207.0              55180            NaN             80.0
# 649            23662.0              44921        78100.0             42.0
#
#      SAT Lower  SAT Upper  ACT Lower  ACT Upper            Website
# 0       1460.0     1590.0       32.0       35.0    www.harvard.edu
# 1       1390.0     1540.0       32.0       35.0   www.stanford.edu
# 2       1460.0     1580.0       32.0       35.0       www.yale.edu
# 3       1490.0     1570.0       33.0       35.0        web.mit.edu
# 4       1430.0     1570.0       31.0       35.0  www.princeton.edu
# ..         ...        ...        ...        ...                ...
# 645      910.0     1160.0       18.0       23.0       www.nmsu.edu
# 646      900.0     1110.0       17.0       23.0   www.indstate.edu
# 647      988.0     1170.0       19.0       25.0        www.ehc.edu
# 648        NaN        NaN        NaN        NaN      www.wells.edu
# 649      930.0     1100.0       18.0       23.0    www.catawba.edu
#
# [650 rows x 17 columns]

# %% [markdown]
# ### Dimension of the data

# %% [markdown]
# *'shape'* is a property associated with DataFrame. It returns a tuple representing the dimensionality of the DataFrame. First value is giving number of rows and second value is giving number of columns.

# %%
forbes_data.shape
# Out:
# (650, 17)

# %% [markdown]
# ### Datatype of the fields in the data

# %% [markdown]
# 'info()' method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage

# %%
forbes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      650 non-null    int64
#  1   Name                      650 non-null    object
#  2   City                      650 non-null    object
#  3   State                     650 non-null    object
#  4   Public/Private            650 non-null    object
#  5   Undergraduate Population  650 non-null    int64
#  6   Student Population        650 non-null    int64
#  7   Net Price                 648 non-null    float64
#  8   Average Grant Aid         646 non-null    float64
#  9   Total Annual Cost         650 non-null    int64
#  10  Alumni Salary             635 non-null    float64
#  11  Acceptance Rate           648 non-null    float64
#  12  SAT Lower                 551 non-null    float64
#  13  SAT Upper                 551 non-null    float64
#  14  ACT Lower                 553 non-null    float64
#  15  ACT Upper                 553 non-null    float64
#  16  Website                   645 non-null    object
# dtypes: float64(8), int64(4), object(5)
# memory usage: 86.5+ KB

# %%
forbes_data.columns
# Out:
# Index(['Rank', 'Name', 'City', 'State', 'Public/Private',
#        'Undergraduate Population', 'Student Population', 'Net Price',
#        'Average Grant Aid', 'Total Annual Cost', 'Alumni Salary',
#        'Acceptance Rate', 'SAT Lower', 'SAT Upper', 'ACT Lower', 'ACT Upper',
#        'Website'],
#       dtype='object')

# %% [markdown]
# ### Check the missing values in the data
# 'isnull()' method detects missing values. It returns a boolean same-sized object indicating if the values are NA. NA values, gets mapped to True values.Everything else gets mapped to False values.
#
# 'sum()' method followed by 'isnull()' adds up all the True instances per column to give a summary of missing values per column

# %%
forbes_data.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %%
forbes_data.isna().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %%
forbes_data.isna()
# Out:
#       Rank   Name   City  State  Public/Private  Undergraduate Population  \
# 0    False  False  False  False           False                     False
# 1    False  False  False  False           False                     False
# 2    False  False  False  False           False                     False
# 3    False  False  False  False           False                     False
# 4    False  False  False  False           False                     False
# ..     ...    ...    ...    ...             ...                       ...
# 645  False  False  False  False           False                     False
# 646  False  False  False  False           False                     False
# 647  False  False  False  False           False                     False
# 648  False  False  False  False           False                     False
# 649  False  False  False  False           False                     False
#
#      Student Population  Net Price  Average Grant Aid  Total Annual Cost  \
# 0                 False      False              False              False
# 1                 False      False              False              False
# 2                 False      False              False              False
# 3                 False      False              False              False
# 4                 False      False              False              False
# ..                  ...        ...                ...                ...
# 645               False      False              False              False
# 646               False      False              False              False
# 647               False      False              False              False
# 648               False      False              False              False
# 649               False      False              False              False
#
#      Alumni Salary  Acceptance Rate  SAT Lower  SAT Upper  ACT Lower  \
# 0            False            False      False      False      False
# 1            False            False      False      False      False
# 2            False            False      False      False      False
# 3            False            False      False      False      False
# 4            False            False      False      False      False
# ..             ...              ...        ...        ...        ...
# 645          False            False      False      False      False
# 646          False            False      False      False      False
# 647          False            False      False      False      False
# 648           True            False       True       True       True
# 649          False            False      False      False      False
#
#      ACT Upper  Website
# 0        False    False
# 1        False    False
# 2        False    False
# 3        False    False
# 4        False    False
# ..         ...      ...
# 645      False    False
# 646      False    False
# 647      False    False
# 648       True    False
# 649      False    False
#
# [650 rows x 17 columns]

# %%
forbes_data.isnull()
# Out:
#       Rank   Name   City  State  Public/Private  Undergraduate Population  \
# 0    False  False  False  False           False                     False
# 1    False  False  False  False           False                     False
# 2    False  False  False  False           False                     False
# 3    False  False  False  False           False                     False
# 4    False  False  False  False           False                     False
# ..     ...    ...    ...    ...             ...                       ...
# 645  False  False  False  False           False                     False
# 646  False  False  False  False           False                     False
# 647  False  False  False  False           False                     False
# 648  False  False  False  False           False                     False
# 649  False  False  False  False           False                     False
#
#      Student Population  Net Price  Average Grant Aid  Total Annual Cost  \
# 0                 False      False              False              False
# 1                 False      False              False              False
# 2                 False      False              False              False
# 3                 False      False              False              False
# 4                 False      False              False              False
# ..                  ...        ...                ...                ...
# 645               False      False              False              False
# 646               False      False              False              False
# 647               False      False              False              False
# 648               False      False              False              False
# 649               False      False              False              False
#
#      Alumni Salary  Acceptance Rate  SAT Lower  SAT Upper  ACT Lower  \
# 0            False            False      False      False      False
# 1            False            False      False      False      False
# 2            False            False      False      False      False
# 3            False            False      False      False      False
# 4            False            False      False      False      False
# ..             ...              ...        ...        ...        ...
# 645          False            False      False      False      False
# 646          False            False      False      False      False
# 647          False            False      False      False      False
# 648           True            False       True       True       True
# 649          False            False      False      False      False
#
#      ACT Upper  Website
# 0        False    False
# 1        False    False
# 2        False    False
# 3        False    False
# 4        False    False
# ..         ...      ...
# 645      False    False
# 646      False    False
# 647      False    False
# 648       True    False
# 649      False    False
#
# [650 rows x 17 columns]

# %% [markdown]
# ### Data Cleanup

# %% [markdown]
# Let's first drop all columns that are not need.
#
# 'drop()' method with 'axis=1' indicates that columns have to be dropped. List of column names to be dropped is passed to the method. 'inplace = True' ensures that the columns are dropped from the DataFrame permanently

# %%
forbes_data.drop(['SAT Lower', 'SAT Upper', 'ACT Lower', 'ACT Upper', 'Website'], axis = 1, inplace= True)

# %%
forbes_data.columns
# Out:
# Index(['Rank', 'Name', 'City', 'State', 'Public/Private',
#        'Undergraduate Population', 'Student Population', 'Net Price',
#        'Average Grant Aid', 'Total Annual Cost', 'Alumni Salary',
#        'Acceptance Rate'],
#       dtype='object')

# %% [markdown]
# 'dropna()' method drops all rows with NA values (by default axis = 0)

# %%
forbes_data.dropna(inplace=True)

# %%
forbes_data.isna().sum()
# Out:
# Rank                        0
# Name                        0
# City                        0
# State                       0
# Public/Private              0
# Undergraduate Population    0
# Student Population          0
# Net Price                   0
# Average Grant Aid           0
# Total Annual Cost           0
# Alumni Salary               0
# Acceptance Rate             0
# dtype: int64

# %% [markdown]
# ### Reset the index of the dataframe
#
# 'reset_index()' resets the index of the DataFrame
#
# 'drop' as True, will not try to insert index into DataFrame columns
#
# 'inplace' as True resets the index permanently

# %%
forbes_data.reset_index()
# Out:
#      index  Rank                                   Name         City State  \
# 0        0     1                     Harvard University    Cambridge    MA
# 1        1     2                    Stanford University     Stanford    CA
# 2        2     3                        Yale University    New Haven    CT
# 3        3     4  Massachusetts Institute of Technology    Cambridge    MA
# 4        4     5                   Princeton University    Princeton    NJ
# ..     ...   ...                                    ...          ...   ...
# 623    644   645                      Morehouse College      Atlanta    GA
# 624    645   646            New Mexico State University   Las Cruces    NM
# 625    646   647               Indiana State University  Terre Haute    IN
# 626    647   648              Emory &amp; Henry College        Emory    VA
# 627    649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# 1          Private                      8402               17534    13261.0
# 2          Private                      6483               12974    18627.0
# 3          Private                      4680               11466    20771.0
# 4          Private                      5659                8273     9327.0
# ..             ...                       ...                 ...        ...
# 623        Private                      2202                2219    34928.0
# 624         Public                     13379               14432     8625.0
# 625         Public                     13626               13763    13012.0
# 626        Private                      1094                1226    19340.0
# 627        Private                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 0              49870.0              69600       146800.0              5.0
# 1              50134.0              69109       145200.0              5.0
# 2              50897.0              71290       138300.0              7.0
# 3              43248.0              67430       155200.0              7.0
# 4              48088.0              66150       139400.0              6.0
# ..                 ...                ...            ...              ...
# 623            17318.0              48723        98700.0             74.0
# 624             9582.0              34720        96700.0             64.0
# 625             9297.0              32938        85600.0             85.0
# 626            27155.0              48100        70700.0             72.0
# 627            23662.0              44921        78100.0             42.0
#
# [628 rows x 13 columns]

# %% [markdown]
# ### Check the first 5 rows of the dataset
# 'head()' function is used to view the top records. By default it displays 5 rows.

# %%
forbes_data.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 0            49870.0              69600       146800.0              5.0
# 1            50134.0              69109       145200.0              5.0
# 2            50897.0              71290       138300.0              7.0
# 3            43248.0              67430       155200.0              7.0
# 4            48088.0              66150       139400.0              6.0

# %%
forbes_data.head(10)
# Out:
#    Rank                                   Name          City State  \
# 0     1                     Harvard University     Cambridge    MA
# 1     2                    Stanford University      Stanford    CA
# 2     3                        Yale University     New Haven    CT
# 3     4  Massachusetts Institute of Technology     Cambridge    MA
# 4     5                   Princeton University     Princeton    NJ
# 5     6             University of Pennsylvania  Philadelphia    PA
# 6     7                       Brown University    Providence    RI
# 7     8     California Institute of Technology      Pasadena    CA
# 8     9                        Duke University        Durham    NC
# 9    10                      Dartmouth College       Hanover    NH
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
# 5        Private                     13437               25367    24242.0
# 6        Private                      7390               10095    30205.0
# 7        Private                      1002                2238    24245.0
# 8        Private                      7184               16130    35737.0
# 9        Private                      4693                6509    30421.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 0            49870.0              69600       146800.0              5.0
# 1            50134.0              69109       145200.0              5.0
# 2            50897.0              71290       138300.0              7.0
# 3            43248.0              67430       155200.0              7.0
# 4            48088.0              66150       139400.0              6.0
# 5            44801.0              71715       133900.0              9.0
# 6            42455.0              71050       127600.0              8.0
# 7            41408.0              68901       151600.0              8.0
# 8            47836.0              71764       132100.0             10.0
# 9            47171.0              71827       130900.0             10.0

# %% [markdown]
# ### Display the last five rows of the dataset
# 'tail()' function is used to view the last records. By default it displays 5 rows.

# %%
forbes_data.tail()
# Out:
#      Rank                         Name         City State Public/Private  \
# 644   645            Morehouse College      Atlanta    GA        Private
# 645   646  New Mexico State University   Las Cruces    NM         Public
# 646   647     Indiana State University  Terre Haute    IN         Public
# 647   648    Emory &amp; Henry College        Emory    VA        Private
# 649   650              Catawba College    Salisbury    NC        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 644                      2202                2219    34928.0
# 645                     13379               14432     8625.0
# 646                     13626               13763    13012.0
# 647                      1094                1226    19340.0
# 649                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 644            17318.0              48723        98700.0             74.0
# 645             9582.0              34720        96700.0             64.0
# 646             9297.0              32938        85600.0             85.0
# 647            27155.0              48100        70700.0             72.0
# 649            23662.0              44921        78100.0             42.0

# %%
forbes_data.tail()
# Out:
#      Rank                         Name         City State Public/Private  \
# 644   645            Morehouse College      Atlanta    GA        Private
# 645   646  New Mexico State University   Las Cruces    NM         Public
# 646   647     Indiana State University  Terre Haute    IN         Public
# 647   648    Emory &amp; Henry College        Emory    VA        Private
# 649   650              Catawba College    Salisbury    NC        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 644                      2202                2219    34928.0
# 645                     13379               14432     8625.0
# 646                     13626               13763    13012.0
# 647                      1094                1226    19340.0
# 649                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 644            17318.0              48723        98700.0             74.0
# 645             9582.0              34720        96700.0             64.0
# 646             9297.0              32938        85600.0             85.0
# 647            27155.0              48100        70700.0             72.0
# 649            23662.0              44921        78100.0             42.0

# %% [markdown]
# ### Recheck the dimension and info of the data

# %%
forbes_data.shape
# Out:
# (628, 12)

# %%
forbes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 628 entries, 0 to 649
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      628 non-null    int64
#  1   Name                      628 non-null    object
#  2   City                      628 non-null    object
#  3   State                     628 non-null    object
#  4   Public/Private            628 non-null    object
#  5   Undergraduate Population  628 non-null    int64
#  6   Student Population        628 non-null    int64
#  7   Net Price                 628 non-null    float64
#  8   Average Grant Aid         628 non-null    float64
#  9   Total Annual Cost         628 non-null    int64
#  10  Alumni Salary             628 non-null    float64
#  11  Acceptance Rate           628 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 63.8+ KB

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Get Summary of Data

# %% [markdown]
# 'describe()' method generates descriptive statistics. Descriptive statistics include those that summarize the central
# tendency, dispersion and shape of a dataset's distribution, excluding 'NaN' values

# %%
forbes_data.describe()
# Out:
#              Rank  Undergraduate Population  Student Population     Net Price  \
# count  628.000000                628.000000          628.000000    628.000000
# mean   322.122611              10235.472930        12312.912420  22481.570064
# std    185.360460              11228.048723        13246.660229   8099.771637
# min      1.000000                323.000000          406.000000   1298.000000
# 25%    161.750000               2062.750000         2294.500000  16476.000000
# 50%    321.500000               4825.500000         6538.500000  22065.000000
# 75%    479.250000              15867.000000        18357.250000  27880.750000
# max    650.000000              65100.000000        75044.000000  47270.000000
#
#        Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# count         628.000000         628.000000     628.000000       628.000000
# mean        19971.522293       50722.579618   98616.242038        61.721338
# std         11214.740998       12670.126944   14026.078146        21.795857
# min          2975.000000        8646.000000   70700.000000         5.000000
# 25%          9253.000000       40076.000000   88600.000000        49.000000
# 50%         19605.000000       50478.000000   96300.000000        67.000000
# 75%         27431.000000       60965.000000  105400.000000        78.000000
# max         50897.000000       75735.000000  158200.000000       100.000000

# %%
forbes_data.describe().T
# Out:
#                           count          mean           std      min  \
# Rank                      628.0    322.122611    185.360460      1.0
# Undergraduate Population  628.0  10235.472930  11228.048723    323.0
# Student Population        628.0  12312.912420  13246.660229    406.0
# Net Price                 628.0  22481.570064   8099.771637   1298.0
# Average Grant Aid         628.0  19971.522293  11214.740998   2975.0
# Total Annual Cost         628.0  50722.579618  12670.126944   8646.0
# Alumni Salary             628.0  98616.242038  14026.078146  70700.0
# Acceptance Rate           628.0     61.721338     21.795857      5.0
#
#                                25%      50%        75%       max
# Rank                        161.75    321.5     479.25     650.0
# Undergraduate Population   2062.75   4825.5   15867.00   65100.0
# Student Population         2294.50   6538.5   18357.25   75044.0
# Net Price                 16476.00  22065.0   27880.75   47270.0
# Average Grant Aid          9253.00  19605.0   27431.00   50897.0
# Total Annual Cost         40076.00  50478.0   60965.00   75735.0
# Alumni Salary             88600.00  96300.0  105400.00  158200.0
# Acceptance Rate              49.00     67.0      78.00     100.0

# %%
forbes_data.describe(include='all').T
# Out:
#                          count unique                          top freq  \
# Rank                       628    NaN                          NaN  NaN
# Name                       628    628  Western Illinois University    1
# City                       628    457                     New York   14
# State                      628     51                           NY   64
# Public/Private             628      2                      Private  384
# Undergraduate Population   628    NaN                          NaN  NaN
# Student Population         628    NaN                          NaN  NaN
# Net Price                  628    NaN                          NaN  NaN
# Average Grant Aid          628    NaN                          NaN  NaN
# Total Annual Cost          628    NaN                          NaN  NaN
# Alumni Salary              628    NaN                          NaN  NaN
# Acceptance Rate            628    NaN                          NaN  NaN
#
#                              mean      std    min      25%     50%      75%  \
# Rank                      322.123   185.36      1   161.75   321.5   479.25
# Name                          NaN      NaN    NaN      NaN     NaN      NaN
# City                          NaN      NaN    NaN      NaN     NaN      NaN
# State                         NaN      NaN    NaN      NaN     NaN      NaN
# Public/Private                NaN      NaN    NaN      NaN     NaN      NaN
# Undergraduate Population  10235.5    11228    323  2062.75  4825.5    15867
# Student Population        12312.9  13246.7    406   2294.5  6538.5  18357.2
# Net Price                 22481.6  8099.77   1298    16476   22065  27880.8
# Average Grant Aid         19971.5  11214.7   2975     9253   19605    27431
# Total Annual Cost         50722.6  12670.1   8646    40076   50478    60965
# Alumni Salary             98616.2  14026.1  70700    88600   96300   105400
# Acceptance Rate           61.7213  21.7959      5       49      67       78
#
#                              max
# Rank                         650
# Name                         NaN
# City                         NaN
# State                        NaN
# Public/Private               NaN
# Undergraduate Population   65100
# Student Population         75044
# Net Price                  47270
# Average Grant Aid          50897
# Total Annual Cost          75735
# Alumni Salary             158200
# Acceptance Rate              100

# %% [markdown]
# ### 1) Which are the top 5 colleges listed in the Forbes Magazine 2019?

# %% [markdown]
# As we need the 'Name' of the colleges, we first pick the 'Name' column and then display the top 5 rows using head() function

# %%
forbes_data.Name.head(5)
# Out:
# 0                       Harvard University
# 1                      Stanford University
# 2                          Yale University
# 3    Massachusetts Institute of Technology
# 4                     Princeton University
# Name: Name, dtype: object

# %% [markdown]
# We can also save the information in an object 'top5' and display it

# %%
forbes_data.Name.head(20)
# Out:
# 0                        Harvard University
# 1                       Stanford University
# 2                           Yale University
# 3     Massachusetts Institute of Technology
# 4                      Princeton University
# 5                University of Pennsylvania
# 6                          Brown University
# 7        California Institute of Technology
# 8                           Duke University
# 9                         Dartmouth College
# 10                       Cornell University
# 11                           Pomona College
# 12       University of California, Berkeley
# 13                      Columbia University
# 14                    Georgetown University
# 15                    University of Chicago
# 16                  Northwestern University
# 17                 University of Notre Dame
# 18                         Williams College
# 19        University of Michigan, Ann Arbor
# Name: Name, dtype: object

# %% [markdown]
# ### 2) Which state and city do the top 5 colleges belong to?

# %% [markdown]
# As we need the 'Name', 'City' and 'State' of the colleges, we first pick the required columns and then display the top 5 rows using head() function

# %%
forbes_data.iloc[0:5,0:4]
# Out:
#    Rank                                   Name       City State
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ

# %% [markdown]
# Note:
#
# As 'City' and 'State' are immediate columns after 'Name', iloc can also be used to get the results

# %%
forbes_data.iloc[:,0:9]
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 644   645                      Morehouse College      Atlanta    GA
# 645   646            New Mexico State University   Las Cruces    NM
# 646   647               Indiana State University  Terre Haute    IN
# 647   648              Emory &amp; Henry College        Emory    VA
# 649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# 1          Private                      8402               17534    13261.0
# 2          Private                      6483               12974    18627.0
# 3          Private                      4680               11466    20771.0
# 4          Private                      5659                8273     9327.0
# ..             ...                       ...                 ...        ...
# 644        Private                      2202                2219    34928.0
# 645         Public                     13379               14432     8625.0
# 646         Public                     13626               13763    13012.0
# 647        Private                      1094                1226    19340.0
# 649        Private                      1336                1463    19807.0
#
#      Average Grant Aid
# 0              49870.0
# 1              50134.0
# 2              50897.0
# 3              43248.0
# 4              48088.0
# ..                 ...
# 644            17318.0
# 645             9582.0
# 646             9297.0
# 647            27155.0
# 649            23662.0
#
# [628 rows x 9 columns]

# %% [markdown]
# ### 3) How many states and which all states have the colleges listed by Forbes?

# %% [markdown]
# 'nunique()' returns number of unique elements in the object. As we want number of unique states, we first pick up the 'State' column of the DataFrame and then call nunique() function

# %%
forbes_data.State.nunique()
# Out:
# 51

# %% [markdown]
# 'unique()' function returns unique values of Series object. Hence, we first pick up the 'State' column of the DataFrame and then call unique() function to get all all the States

# %%
forbes_data.State.unique()
# Out:
# array(['MA', 'CA', 'CT', 'NJ', 'PA', 'RI', 'NC', 'NH', 'NY', 'DC', 'IL',
#        'IN', 'MI', 'TX', 'MD', 'ME', 'TN', 'MO', 'VA', 'VT', 'MN', 'GA',
#        'WA', 'WI', 'FL', 'OH', 'IA', 'CO', 'UT', 'OR', 'LA', 'SC', 'DE',
#        'AL', 'AZ', 'OK', 'NE', 'KY', 'KS', 'AR', 'WY', 'NV', 'MS', 'ND',
#        'HI', 'MT', 'SD', 'NM', 'ID', 'WV', 'AK'], dtype=object)

# %% [markdown]
# ### 4) In all how many private and public colleges are there in the given list?

# %% [markdown]
# 'Public/Private' column is of object data type in the DataFrame.
#
# 'value_count()' returns a series containing counts of unique values

# %%
forbes_data['Public/Private'].value_counts()
# Out:
# Private    384
# Public     244
# Name: Public/Private, dtype: int64

# %% [markdown]
# ### 5) From the list how many colleges are there within each State? Which State has highest number of colleges?

# %% [markdown]
# As we have to find number of colleges within each State, we first group (groupby()) the data based on 'State'. For each State we then count the colleges using number of unique values (nunique())  in 'Name' field.
#
# As we want the 'State' with highest number of colleges, we sort the values (sort_values()) in descending order to get the results.

# %%
forbes_data.groupby(by = 'State').Name.nunique().sort_values(ascending = False)
# Out:
# State
# NY    64
# CA    56
# PA    39
# MA    31
# OH    29
# IL    25
# TX    25
# FL    20
# NC    19
# VA    18
# IN    18
# MN    18
# MI    16
# GA    14
# TN    14
# NJ    13
# IA    13
# WI    13
# WA    12
# KY    12
# MD    12
# MO    12
# CO    11
# OR    11
# CT     9
# LA     8
# SC     8
# AL     7
# RI     7
# NE     6
# OK     6
# MS     5
# DC     5
# ME     5
# AZ     4
# MT     4
# ID     4
# SD     4
# UT     4
# VT     4
# AR     4
# KS     3
# NH     3
# NM     3
# AK     2
# ND     2
# NV     2
# DE     1
# HI     1
# WV     1
# WY     1
# Name: Name, dtype: int64

# %% [markdown]
# ### 6) What is percentage of undergraduates in each college? (Add a new field to calculate)

# %% [markdown]
# Divsion of 'Undergraduate Population' by 'Student Population' multiplied by 100 will give percentage of undergraduates.
#
# round() method will round off the derived value to 2 decimal places which is then stored in new field 'Percentage UG'

# %%
forbes_data['Percentage UG'] = round(forbes_data['Undergraduate Population']/forbes_data['Student Population']*100, 2)

# %%
forbes_data
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 644   645                      Morehouse College      Atlanta    GA
# 645   646            New Mexico State University   Las Cruces    NM
# 646   647               Indiana State University  Terre Haute    IN
# 647   648              Emory &amp; Henry College        Emory    VA
# 649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# 1          Private                      8402               17534    13261.0
# 2          Private                      6483               12974    18627.0
# 3          Private                      4680               11466    20771.0
# 4          Private                      5659                8273     9327.0
# ..             ...                       ...                 ...        ...
# 644        Private                      2202                2219    34928.0
# 645         Public                     13379               14432     8625.0
# 646         Public                     13626               13763    13012.0
# 647        Private                      1094                1226    19340.0
# 649        Private                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 0              49870.0              69600       146800.0              5.0
# 1              50134.0              69109       145200.0              5.0
# 2              50897.0              71290       138300.0              7.0
# 3              43248.0              67430       155200.0              7.0
# 4              48088.0              66150       139400.0              6.0
# ..                 ...                ...            ...              ...
# 644            17318.0              48723        98700.0             74.0
# 645             9582.0              34720        96700.0             64.0
# 646             9297.0              32938        85600.0             85.0
# 647            27155.0              48100        70700.0             72.0
# 649            23662.0              44921        78100.0             42.0
#
#      Percentage UG
# 0            44.49
# 1            47.92
# 2            49.97
# 3            40.82
# 4            68.40
# ..             ...
# 644          99.23
# 645          92.70
# 646          99.00
# 647          89.23
# 649          91.32
#
# [628 rows x 13 columns]

# %% [markdown]
# ### 7) Which are the 5 colleges with highest percentage of undergraduates?

# %% [markdown]
# Let's just pick up 'Name' and 'Percentage UG' field, sort by 'Percentage UG' in descending order to get the desired ouput

# %%
forbes_data[['Name', 'Percentage UG']].sort_values(by= 'Percentage UG', ascending = False).head(5)
# Out:
#                                        Name  Percentage UG
# 570  University of Texas, Rio Grande Valley          99.99
# 253            Saint John's University (MN)          99.94
# 565                      Oakland University          99.94
# 364                    Salisbury University          99.92
# 345                     St. Norbert College          99.86

# %% [markdown]
# ### 8) 5 colleges that receive highest Average Grant Aid?

# %% [markdown]
# Sort 'Average Grant Aid' in descending order and pick up the top 5 colleges using 'Name' field

# %%
forbes_data.sort_values(by= 'Average Grant Aid', ascending = False).Name.head(5)
# Out:
# 2         Yale University
# 1     Stanford University
# 0      Harvard University
# 27        Amherst College
# 13    Columbia University
# Name: Name, dtype: object

# %% [markdown]
# ### 9) What is the average Undergraduate population in State of 'CA'?

# %% [markdown]
# First lets filter the DataFrame and get only rows with 'State' as 'CA'
#
# We then pick up the 'Undergraduate Population' for the above subset and calculate its mean
#
# round off the final value to 2 decimal places using the round() function

# %%
round(forbes_data[forbes_data.State == 'CA']['Undergraduate Population'].mean(),2)
# Out:
# 13186.91

# %% [markdown]
# ### 10) Which are the colleges where chances of admission is high?

# %% [markdown]
# As per the data dictionary 'Acceptance Rate' field provides information on chances of admission. We can sort this column in descending order to get the results

# %%
forbes_data.sort_values(by = 'Acceptance Rate', ascending = False).head()
# Out:
#      Rank                                Name         City State  \
# 605   606        University of Texas, El Paso      El Paso    TX
# 626   627  University of Southern Mississippi  Hattiesburg    MS
# 346   347               University of Wyoming      Laramie    WY
# 637   638             Wright State University       Dayton    OH
# 307   308              University of Kentucky    Lexington    KY
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 605         Public                     24386               25078     8135.0
# 626         Public                     13606               14478    13178.0
# 346         Public                     10874               12397    13070.0
# 637         Public                     14332               15957    16249.0
# 307         Public                     23718               29465    18527.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 605             9183.0              36955        92100.0            100.0
# 626             9292.0              24883        83900.0             98.0
# 346             7422.0              31387        98800.0             97.0
# 637             6546.0              32506        87800.0             97.0
# 307             9387.0              45634        96400.0             96.0
#
#      Percentage UG
# 605          97.24
# 626          93.98
# 346          87.71
# 637          89.82
# 307          80.50

# %% [markdown]
# ### 11) Find if there are any 'Art' colleges in the list

# %% [markdown]
# To find a specific string value 'Art' we will use the 'contains()' method. We will pass the string in the paranthesis which needs to be located in the dataframe variable.

# %%
forbes_data[forbes_data['Name'].str.contains('Art')]
# Out:
#      Rank                               Name           City State  \
# 302   303  Maryland Institute College of Art      Baltimore    MD
# 401   402   California Institute of the Arts  Santa Clarita    CA
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 302        Private                      2041                2128    38763.0
# 401        Private                       991                1498    46101.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 302            18939.0              62850        84500.0             62.0
# 401            15401.0              68993        91000.0             24.0
#
#      Percentage UG
# 302          95.91
# 401          66.15

# %% [markdown]
# ### 12) Lets divide the Alumni Salary equally into 3 buckets (Low Salary - L; Medium Salary - M; High Salary - H ) and check which colleges falls in 'H' bucket

# %%
forbes_data2 = forbes_data.copy()

# %% [markdown]
# Take a copy of the original DataFrame to work on

# %%
forbes_data2[' Alumni Salary Level']= pd.cut(forbes_data2["Alumni Salary"], 3, labels = ['L', 'M', 'H'])

# %% [markdown]
# 'cut()' function bins values into discrete intervals. 'cut()' function is used when you need to segment and sort data values into bins. This function is also useful for going from a continuous variable to a categorical variable.
#
# In the above code we have created 3 bins using 'Alumni Salary' column. Lowest range of salary is labelled as 'L', middle range is labelled as 'M' and highest range of salary is labelled as 'H'. These labels are saved in a new column 'Alumni Sal Level'.
#
# Note: The entire range of the 'Alumni Salary' has been divided into 3 equal ranges i.e. 3 bins

# %%
forbes_data2.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 0            49870.0              69600       146800.0              5.0
# 1            50134.0              69109       145200.0              5.0
# 2            50897.0              71290       138300.0              7.0
# 3            43248.0              67430       155200.0              7.0
# 4            48088.0              66150       139400.0              6.0
#
#    Percentage UG  Alumni Salary Level
# 0          44.49                    H
# 1          47.92                    H
# 2          49.97                    H
# 3          40.82                    H
# 4          68.40                    H

# %%
forbes_data2[' Alumni Salary Level'].value_counts()
# Out:
# L    383
# M    217
# H     28
# Name:  Alumni Salary Level, dtype: int64

# %% [markdown]
# ### 13) Let's check the mean Alumni Salary at each level

# %%
round(forbes_data2.groupby(' Alumni Salary Level')['Alumni Salary'].mean(),2)
# Out:
#  Alumni Salary Level
# L     89835.77
# M    109086.64
# H    137575.00
# Name: Alumni Salary, dtype: float64

# %% [markdown]
# ### 14) Let's create a new dataframe to further analyze the 28 colleges with High Alumni Salary

# %%
forbes_data_AlumSal = forbes_data2[forbes_data2[' Alumni Salary Level']== 'H']

# %%
forbes_data_AlumSal
# Out:
#      Rank                                          Name          City State  \
# 0       1                            Harvard University     Cambridge    MA
# 1       2                           Stanford University      Stanford    CA
# 2       3                               Yale University     New Haven    CT
# 3       4         Massachusetts Institute of Technology     Cambridge    MA
# 4       5                          Princeton University     Princeton    NJ
# 5       6                    University of Pennsylvania  Philadelphia    PA
# 7       8            California Institute of Technology      Pasadena    CA
# 8       9                               Duke University        Durham    NC
# 9      10                             Dartmouth College       Hanover    NH
# 12     13            University of California, Berkeley      Berkeley    CA
# 17     18                      University of Notre Dame    Notre Dame    IN
# 20     21                               Rice University       Houston    TX
# 22     23                           Harvey Mudd College     Claremont    CA
# 36     37                    Carnegie Mellon University    Pittsburgh    PA
# 45     46                            Colgate University      Hamilton    NY
# 50     51                        Santa Clara University   Santa Clara    CA
# 61     62                                Babson College   Babson Park    MA
# 64     65               Georgia Institute of Technology       Atlanta    GA
# 65     66         United States Merchant Marine Academy   Kings Point    NY
# 66     67                             Lehigh University     Bethlehem    PA
# 92     93               Worcester Polytechnic Institute     Worcester    MA
# 93     94                      Colorado School of Mines        Golden    CO
# 109   110           Rose-Hulman Institute of Technology   Terre Haute    IN
# 112   113              Rensselaer Polytechnic Institute          Troy    NY
# 151   152               Stevens Institute of Technology       Hoboken    NJ
# 206   207                           Clarkson University       Potsdam    NY
# 308   309  California State University Maritime Academy       Vallejo    CA
# 332   333                         SUNY Maritime College  Throggs Neck    NY
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0          Private                     13844               31120    14327.0
# 1          Private                      8402               17534    13261.0
# 2          Private                      6483               12974    18627.0
# 3          Private                      4680               11466    20771.0
# 4          Private                      5659                8273     9327.0
# 5          Private                     13437               25367    24242.0
# 7          Private                      1002                2238    24245.0
# 8          Private                      7184               16130    35737.0
# 9          Private                      4693                6509    30421.0
# 12          Public                     31133               41891    15859.0
# 17         Private                      8664               12467    28768.0
# 20         Private                      4036                7022    20237.0
# 22         Private                       847                 861    34464.0
# 36         Private                      6941               13869    31102.0
# 45         Private                      2894                3025    23310.0
# 50         Private                      5754                8629    33738.0
# 61         Private                      2354                3329    35540.0
# 64          Public                     17223               29376    13291.0
# 65          Public                       912                 975     6758.0
# 66         Private                      5337                7017    34212.0
# 92         Private                      4654                6642    40376.0
# 93          Public                      4811                6209    25710.0
# 109        Private                      2245                2254    36906.0
# 112        Private                      6371                7592    34839.0
# 151        Private                      3144                6916    36620.0
# 206        Private                      3335                4233    30563.0
# 308         Public                      1090                1181    16416.0
# 332         Public                      1778                1794    18413.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 0              49870.0              69600       146800.0              5.0
# 1              50134.0              69109       145200.0              5.0
# 2              50897.0              71290       138300.0              7.0
# 3              43248.0              67430       155200.0              7.0
# 4              48088.0              66150       139400.0              6.0
# 5              44801.0              71715       133900.0              9.0
# 7              41408.0              68901       151600.0              8.0
# 8              47836.0              71764       132100.0             10.0
# 9              47171.0              71827       130900.0             10.0
# 12             18319.0              65003       131800.0             17.0
# 17             39590.0              69395       130500.0             19.0
# 20             36387.0              63158       129500.0             16.0
# 22             33782.0              74428       158200.0             15.0
# 36             38163.0              70094       136100.0             22.0
# 45             45108.0              69860       130600.0             28.0
# 50             26671.0              69439       134700.0             54.0
# 61             36717.0              68432       133800.0             24.0
# 64             12779.0              49366       133400.0             23.0
# 65              3597.0               8646       140700.0             22.0
# 66             36014.0              65925       134100.0             25.0
# 92             19515.0              65046       135500.0             48.0
# 93             10725.0              52698       139600.0             56.0
# 109            20967.0              65031       135800.0             61.0
# 112            30596.0              70132       134100.0             43.0
# 151            25762.0              67204       139900.0             44.0
# 206            32540.0              66106       130100.0             66.0
# 308             7716.0              39962       129600.0             66.0
# 332             7134.0              34958       140700.0             69.0
#
#      Percentage UG  Alumni Salary Level
# 0            44.49                    H
# 1            47.92                    H
# 2            49.97                    H
# 3            40.82                    H
# 4            68.40                    H
# 5            52.97                    H
# 7            44.77                    H
# 8            44.54                    H
# 9            72.10                    H
# 12           74.32                    H
# 17           69.50                    H
# 20           57.48                    H
# 22           98.37                    H
# 36           50.05                    H
# 45           95.67                    H
# 50           66.68                    H
# 61           70.71                    H
# 64           58.63                    H
# 65           93.54                    H
# 66           76.06                    H
# 92           70.07                    H
# 93           77.48                    H
# 109          99.60                    H
# 112          83.92                    H
# 151          45.46                    H
# 206          78.79                    H
# 308          92.29                    H
# 332          99.11                    H

# %% [markdown]
# Passing 'include = 'all'' to describe() method provides descriptive summary of all fields in the DataFrame. 'T' property transposes the table which helps in reviewing the statistics per column

# %%
forbes_data_AlumSal.describe(include = 'all')
# Out:
#               Rank                Name       City State Public/Private  \
# count    28.000000                  28         28    28             28
# unique         NaN                  28         27    12              2
# top            NaN  Harvard University  Cambridge    CA        Private
# freq           NaN                   1          2     6             22
# mean     68.857143                 NaN        NaN   NaN            NaN
# std      87.500144                 NaN        NaN   NaN            NaN
# min       1.000000                 NaN        NaN   NaN            NaN
# 25%       8.750000                 NaN        NaN   NaN            NaN
# 50%      41.500000                 NaN        NaN   NaN            NaN
# 75%      93.250000                 NaN        NaN   NaN            NaN
# max     333.000000                 NaN        NaN   NaN            NaN
#
#         Undergraduate Population  Student Population     Net Price  \
# count                  28.000000           28.000000     28.000000
# unique                       NaN                 NaN           NaN
# top                          NaN                 NaN           NaN
# freq                         NaN                 NaN           NaN
# mean                 6389.535714        10603.321429  25288.571429
# std                  6290.912467        10225.926422   9526.081595
# min                   847.000000          861.000000   6758.000000
# 25%                  2759.000000         3253.000000  17913.750000
# 50%                  4752.000000         7019.500000  24977.500000
# 75%                  7001.750000        13197.750000  34275.000000
# max                 31133.000000        41891.000000  40376.000000
#
#         Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# count           28.000000          28.000000      28.000000        28.000000
# unique                NaN                NaN            NaN              NaN
# top                   NaN                NaN            NaN              NaN
# freq                  NaN                NaN            NaN              NaN
# mean         32340.535714       62952.464286  137575.000000        28.035714
# std          14681.882361       14203.545967    7667.566372        21.489846
# min           3597.000000        8646.000000  129500.000000         5.000000
# 25%          20604.000000       65024.000000  132025.000000         9.750000
# 50%          36200.500000       67931.000000  135100.000000        22.000000
# 75%          44877.750000       69918.500000  140100.000000        45.000000
# max          50897.000000       74428.000000  158200.000000        69.000000
#
#         Percentage UG  Alumni Salary Level
# count       28.000000                   28
# unique            NaN                    1
# top               NaN                    H
# freq              NaN                   28
# mean        68.703929                  NaN
# std         19.094700                  NaN
# min         40.820000                  NaN
# 25%         50.030000                  NaN
# 50%         69.785000                  NaN
# 75%         80.072500                  NaN
# max         99.600000                  NaN
